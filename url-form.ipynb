# %%
import re
import pandas as pd

#assuming i have access to the dataset as a pandas dataframe
def extract_url(xml):
    match = re.search(r'<url>https?://([a-zA-Z0-9_.]+)</url>', xml)
    if match:
        return match.group(1)
    else:
        None

df['Extracted_URL'] = df['Stats_Access_Link'].apply(extract_url)
